# %%
import os

import pandas as pd
import numpy as np

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy
app = Flask(__name__)

# %%
engine = create_engine('postgresql://postgres:,rc!7YVI@localhost/ISS')
connection = engine.connect()
app.config['SQLALCHEMY_DATABASE_URI'] = 'postgresql://postgres:,rc!7YVI@localhost/ISS'
db = SQLAlchemy(app)
# Out:
# /Users/saniaahmad/anaconda3/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['locations']

# %%
ISS_Locations = Base.classes.locations

# %%
stmt = db.session.query(ISS_Locations).statement
df = pd.read_sql_query(stmt, db.session.bind)

# %%
ISS_Locations
# Out:
# sqlalchemy.ext.automap.locations

# %%
stmt
# Out:
# <sqlalchemy.sql.selectable.Select at 0x115374550; Select object>

# %%
df
# Out:
#                     date  visible   max_height               appears  \
# 0     Wed Oct 2, 8:01 PM    2 min  12 degrees     10 degrees above N
# 1     Thu Oct 3, 7:13 PM    1 min  10 degrees     10 degrees above N
# 2     Thu Oct 3, 8:48 PM    1 min  19 degrees   10 degrees above NNW
# 3     Fri Oct 4, 8:00 PM    3 min  19 degrees   10 degrees above NNW
# 4     Sat Oct 5, 7:12 PM    4 min  15 degrees   10 degrees above NNW
# 5     Sat Oct 5, 8:48 PM    1 min  28 degrees    13 degrees above NW
# 6     Sun Oct 6, 7:59 PM    4 min  41 degrees    10 degrees above NW
# 7     Mon Oct 7, 7:11 PM    6 min  26 degrees   10 degrees above NNW
# 8     Mon Oct 7, 8:49 PM  < 1 min  26 degrees     20 degrees above W
# 9     Tue Oct 8, 8:00 PM    3 min  66 degrees   23 degrees above WNW
# 10    Wed Oct 9, 7:11 PM    6 min  66 degrees    10 degrees above NW
# 11    Wed Oct 9, 8:49 PM    1 min  11 degrees   10 degrees above WSW
# 12   Thu Oct 10, 8:01 PM    3 min  21 degrees   20 degrees above WSW
# 13   Fri Oct 11, 7:13 PM    3 min  38 degrees   36 degrees above WSW
# 14   Sun Oct 13, 7:13 PM    1 min  12 degrees    12 degrees above SW
# 15    Wed Oct 2, 8:01 PM    2 min  12 degrees     10 degrees above N
# 16    Thu Oct 3, 7:13 PM  < 1 min  10 degrees     10 degrees above N
# 17    Thu Oct 3, 8:48 PM    1 min  19 degrees   10 degrees above NNW
# 18    Fri Oct 4, 8:00 PM    3 min  19 degrees   10 degrees above NNW
# 19    Sat Oct 5, 7:12 PM    4 min  14 degrees   10 degrees above NNW
# 20    Sat Oct 5, 8:48 PM    1 min  28 degrees    13 degrees above NW
# 21    Sun Oct 6, 8:00 PM    4 min  41 degrees    10 degrees above NW
# 22    Mon Oct 7, 7:11 PM    6 min  26 degrees   10 degrees above NNW
# 23    Mon Oct 7, 8:49 PM  < 1 min  26 degrees     19 degrees above W
# 119  Sun Oct 13, 7:13 PM    1 min  12 degrees    12 degrees above SW
#
#                disappears        city   id
# 0    11 degrees above NNE  Chantilly     1
# 1    10 degrees above NNE  Chantilly     2
# 2    19 degrees above NNW  Chantilly     3
# 3    19 degrees above NNE  Chantilly     4
# 4     10 degrees above NE  Chantilly     5
# 5     28 degrees above NW  Chantilly     6
# 6    37 degrees above ENE  Chantilly     7
# 7      10 degrees above E  Chantilly     8
# 8      26 degrees above W  Chantilly     9
# 9    36 degrees above SSE  Chantilly    10
# 10   11 degrees above ESE  Chantilly    11
# 11    11 degrees above SW  Chantilly    12
# 12     10 degrees above S  Chantilly    13
# 13   11 degrees above SSE  Chantilly    14
# 14   10 degrees above SSW  Chantilly    15
# 15   11 degrees above NNE      Burke    16
# 16   10 degrees above NNE      Burke    17
# 17   19 degrees above NNW      Burke    18
# 18   19 degrees above NNE      Burke    19
# 19    10 degrees above NE      Burke    20
# 20    28 degrees above NW      Burke    21
# 21   37 degrees above ENE      Burke    22
# 22     10 degrees above E      Burke    23
# 23     26 degrees above W      Burke    24
# 24   36 degrees above SSE      Burke    25
# 25   11 degrees above ESE      Burke    26
# 26    11 degrees above SW      Burke    27
# 27     10 degrees above S      Burke    28
# 28   11 degrees above SSE      Burke    29
# 29   10 degrees above SSW      Burke    30
# ..                    ...         ...  ...
# 90   12 degrees above NNE   Bethesda    91
# 91   10 degrees above NNE   Bethesda    92
# 92   19 degrees above NNW   Bethesda    93
# 93   20 degrees above NNE   Bethesda    94
# 94    10 degrees above NE   Bethesda    95
# 95    28 degrees above NW   Bethesda    96
# 96   38 degrees above ENE   Bethesda    97
# 97     10 degrees above E   Bethesda    98
# 98     26 degrees above W   Bethesda    99
# 99   36 degrees above SSE   Bethesda   100
# 100  11 degrees above ESE   Bethesda   101
# 101   11 degrees above SW   Bethesda   102
# 102    11 degrees above S   Bethesda   103
# 103  11 degrees above SSE   Bethesda   104
# 104  10 degrees above SSW   Bethesda   105
# 105  11 degrees above NNE    Herndon   106
# 106  10 degrees above NNE    Herndon   107
# 107  19 degrees above NNW    Herndon   108
# 108   19 degrees above NE    Herndon   109
# 109   10 degrees above NE    Herndon   110
# 110   28 degrees above NW    Herndon   111
# 111  37 degrees above ENE    Herndon   112
# 112    10 degrees above E    Herndon   113
# 113    26 degrees above W    Herndon   114
# 114  36 degrees above SSE    Herndon   115
# 115  11 degrees above ESE    Herndon   116
# 116   11 degrees above SW    Herndon   117
# 117    11 degrees above S    Herndon   118
# 118  11 degrees above SSE    Herndon   119
# 119  10 degrees above SSW    Herndon   120
#
# [120 rows x 7 columns]

# %%
return jsonify(list(df.columns)[2:])
# Out:
#   File "<ipython-input-19-6a7b3708e851>", line 1
#     return jsonify(list(df.columns)[2:])
#                                         ^
# SyntaxError: 'return' outside function
